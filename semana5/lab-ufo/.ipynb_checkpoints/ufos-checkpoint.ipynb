# %% [markdown]
# # UFO Question
#
# Our data science team has predicted that the Earth is going to be invaded by an alien force in the
# next years. Our only hope is to replicate a device that can block all alien technology in a radius of
# ~300km. Sadly, the device was sold in 2004 to an anonymous buyer to protect her hometown and
# we don't know how contact her again. We know that the device has been active since 2004 in one
# city in the USA, and we want to know where to start our search.
# We've included a dataset called ​ufo.csv​. This dataset contains over 80,000 reports of UFO sightings
# over the last century (all of them verified by the ESA). Using this dataset, try to guess the city in
# which the device has been hidden.

# %%
# Import libraries
import pandas as pd
import numpy as np
import folium

# %%
# Import data

ufo_df = pd.read_csv("ufo.csv")
ufo_df.head()
# Out:
#    Unnamed: 0          datetime                  city state country     shape  \
# 0           0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1           1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2           2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3           3  10/10/1956 21:00                  edna    tx      us    circle
# 4           4  10/10/1960 20:00               kaneohe    hi      us     light
#
#    duration  total_time                                           comments  \
# 0    2700.0  45 minutes  This event took place in early fall around 194...
# 1    7200.0     1-2 hrs  1949 Lackland AFB&#44 TX.  Lights racing acros...
# 2      20.0  20 seconds  Green/Orange circular disc over Chester&#44 En...
# 3      20.0    1/2 hour  My older brother and twin sister were leaving ...
# 4     900.0  15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
#
#   date_posted   latitude   longitude  year     distance
# 0   4/27/2004  29.883056  -97.941111  2004  1242.667772
# 1  12/16/2005  29.384210  -98.581082  2005  1325.486319
# 2   1/21/2008  53.200000   -2.916667  2008  6515.416577
# 3   1/17/2004  28.978333  -96.645833  2004  1211.971352
# 4   1/22/2004  21.418056 -157.803611  2004  6960.923396

# %%
ufo_df.dtypes
# Out:
# Unnamed: 0       int64
# datetime        object
# city            object
# state           object
# country         object
# shape           object
# duration       float64
# total_time      object
# comments        object
# date_posted     object
# latitude       float64
# longitude      float64
# year             int64
# distance       float64
# dtype: object

# %%
ufo_df.isna().sum()
# Out:
# Unnamed: 0        0
# datetime          0
# city              0
# state          5795
# country        9562
# shape          1910
# duration          0
# total_time        0
# comments         14
# date_posted       0
# latitude          0
# longitude         0
# year              0
# distance          0
# dtype: int64

# %%
# Select data
usa_2004_observed = ufo_df[(ufo_df["country"] == "us") & (ufo_df["year"] >= 2004)]

# %%
# Find the city
usa_2004_observed
# Out:
#        Unnamed: 0          datetime        city state country     shape  \
# 0               0  10/10/1949 20:30  san marcos    tx      us  cylinder
# 3               3  10/10/1956 21:00        edna    tx      us    circle
# 4               4  10/10/1960 20:00     kaneohe    hi      us     light
# 5               5  10/10/1961 19:00     bristol    tn      us    sphere
# 8               9  10/10/1966 21:00    live oak    fl      us      disk
# ...           ...               ...         ...   ...     ...       ...
# 78504       80326    9/9/2013 21:00   woodstock    ga      us    sphere
# 78505       80328    9/9/2013 22:00       boise    id      us    circle
# 78506       80329    9/9/2013 22:00        napa    ca      us     other
# 78507       80330    9/9/2013 22:20      vienna    va      us    circle
# 78508       80331    9/9/2013 23:00      edmond    ok      us     cigar
#
#        duration       total_time  \
# 0        2700.0       45 minutes
# 3          20.0         1/2 hour
# 4         900.0       15 minutes
# 5         300.0        5 minutes
# 8         120.0  several minutes
# ...         ...              ...
# 78504      20.0       20 seconds
# 78505    1200.0       20 minutes
# 78506    1200.0             hour
# 78507       5.0        5 seconds
# 78508    1020.0       17 minutes
#
#                                                 comments date_posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# 5      My father is now 89 my brother 52 the girl wit...   4/27/2007
# 8      Saucer zaps energy from powerline as my pregna...   5/11/2005
# ...                                                  ...         ...
# 78504  Driving 575 at 21:00 hrs saw a white and green...   9/30/2013
# 78505  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 78506                                       Napa UFO&#44   9/30/2013
# 78507  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 78508  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#         latitude   longitude  year     distance
# 0      29.883056  -97.941111  2004  1242.667772
# 3      28.978333  -96.645833  2004  1211.971352
# 4      21.418056 -157.803611  2004  6960.923396
# 5      36.595000  -82.188889  2007   427.334113
# 8      30.294722  -82.984167  2005   749.440164
# ...          ...         ...   ...          ...
# 78504  34.101389  -84.519444  2013   318.719195
# 78505  43.613611 -116.202500  2013  2620.021539
# 78506  38.297222 -122.284444  2013  3126.991417
# 78507  38.901111  -77.265556  2013   904.740389
# 78508  35.652778  -97.477778  2013   953.748462
#
# [47126 rows x 14 columns]

# %%
# Generate the folium map object
def generateBaseMap(default_location=[40.693943, -93.985880], default_zoom_start=4):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# generateBaseMap()

# %%
from folium.plugins import HeatMap


usa_2004_observed['count'] = 1
base_map = generateBaseMap()
HeatMap(data=usa_2004_observed[['latitude', 'longitude', 'count']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)
base_map
# Out:
# C:\Users\alex_\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
usa_2004_observed[usa_2004_observed["state"] == "tn"]
# Out:
#        Unnamed: 0          datetime          city state country     shape  \
# 5               5  10/10/1961 19:00       bristol    tn      us    sphere
# 253           262  10/10/2012 21:00  bean station    tn      us     cigar
# 871           894   10/1/2008 22:55     kingsport    tn      us  triangle
# 877           900   10/1/2009 18:00       memphis    tn      us      oval
# 954           979   10/1/2013 21:40    sneedville    tn      us    circle
# ...           ...               ...           ...   ...     ...       ...
# 77160       78947    9/3/2008 21:20   blountville    tn      us     other
# 77161       78948    9/3/2008 21:20   blountville    tn      us     other
# 77327       79117    9/4/2004 19:54       bristol    tn      us     other
# 77414       79207    9/4/2011 00:00       newport    tn      us  triangle
# 77544       79341    9/5/2004 02:00  johnson city    tn      us  fireball
#
#        duration                 total_time  \
# 5         300.0                  5 minutes
# 253       180.0                  3 minutes
# 871         3.0                  3 seconds
# 877       300.0  twice - 1-5 minute sighti
# 954        90.0              1-1.5 minutes
# ...         ...                        ...
# 77160     600.0                 10 minutes
# 77161     600.0                 10 minutes
# 77327     480.0                  8 minutes
# 77414     180.0                      3 min
# 77544      20.0            under 2 seconds
#
#                                                 comments date_posted  \
# 5      My father is now 89 my brother 52 the girl wit...   4/27/2007
# 253    Large cigar shaped flying about 800 feet high....  10/30/2012
# 871             East Tennessee&#44 3 orb mass in the sky  10/31/2008
# 877    Day and Night - Saw object twice c.2009.  3-wi...   5/13/2012
# 954    Large round bright white light moved away and ...   10/3/2013
# ...                                                  ...         ...
# 77160  B2 shaped vehical at low altitude moving in to...    9/9/2013
# 77161  B2 shaped vehicle 20 feet above trees moving i...   9/30/2013
# 77327  Lobed object seen moving westerly at high alti...    9/9/2004
# 77414            black triangle newport tn  cocke county  12/12/2011
# 77544                                     Shooting star?    9/9/2004
#
#         latitude  longitude  year    distance  count
# 5      36.595000 -82.188889  2007  427.334113      1
# 253    36.343611 -83.284167  2012  327.673382      1
# 871    36.548333 -82.561944  2008  393.633851      1
# 877    35.149444 -90.048889  2012  305.272767      1
# 954    36.529722 -83.217500  2013  334.973875      1
# ...          ...        ...   ...         ...    ...
# 77160  36.533056 -82.326944  2013  414.493073      1
# 77161  36.533056 -82.326944  2013  414.493073      1
# 77327  36.595000 -82.188889  2004  427.334113      1
# 77414  35.966944 -83.187778  2011  337.554909      1
# 77544  36.313333 -82.353611  2004  411.131463      1
#
# [209 rows x 15 columns]

# %%
# usa_2004_observed_1 = usa_2004_observed[usa_2004_observed["state"] == "tn"]
# usa_2004_observed_1.head()
# usa_2004_observed_1['count'] = 1
# base_map_1 = generateBaseMap()
# HeatMap(data=usa_2004_observed_1[['latitude', 'longitude', 'count']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)
# base_map_1
# Out:
#      Unnamed: 0          datetime          city state country     shape  \
# 5             5  10/10/1961 19:00       bristol    tn      us    sphere
# 253         262  10/10/2012 21:00  bean station    tn      us     cigar
# 871         894   10/1/2008 22:55     kingsport    tn      us  triangle
# 877         900   10/1/2009 18:00       memphis    tn      us      oval
# 954         979   10/1/2013 21:40    sneedville    tn      us    circle
#
#      duration                 total_time  \
# 5       300.0                  5 minutes
# 253     180.0                  3 minutes
# 871       3.0                  3 seconds
# 877     300.0  twice - 1-5 minute sighti
# 954      90.0              1-1.5 minutes
#
#                                               comments date_posted   latitude  \
# 5    My father is now 89 my brother 52 the girl wit...   4/27/2007  36.595000
# 253  Large cigar shaped flying about 800 feet high....  10/30/2012  36.343611
# 871           East Tennessee&#44 3 orb mass in the sky  10/31/2008  36.548333
# 877  Day and Night - Saw object twice c.2009.  3-wi...   5/13/2012  35.149444
# 954  Large round bright white light moved away and ...   10/3/2013  36.529722
#
#      longitude  year    distance  count
# 5   -82.188889  2007  427.334113      1
# 253 -83.284167  2012  327.673382      1
# 871 -82.561944  2008  393.633851      1
# 877 -90.048889  2012  305.272767      1
# 954 -83.217500  2013  334.973875      1
